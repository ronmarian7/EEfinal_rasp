# %%
import cv2
import torch
torch.cuda.is_available()
# Out:
# True

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("working on gpu")
else:
    device = torch.device("cpu")
    print("working on cpu")
# Out:
# working on gpu

# %%
from IPython import display
display.clear_output()

import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.83 🚀 Python-3.10.11 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce GTX 1070, 8114MiB)
# Setup complete ✅ (12 CPUs, 15.5 GB RAM, 117.0/467.9 GB disk)

# %%
def force_cudnn_initialization():
    s = 32
    dev = torch.device('cuda')
    torch.nn.functional.conv2d(torch.zeros(s, s, s, s, device=dev), torch.zeros(s, s, s, s, device=dev))

force_cudnn_initialization()

# %%
model = YOLO("yolov8s.pt")

results = model.train(data="../dnn_model/yolov8_breed/yolov8_breed.yaml", epochs=50, patience=5, imgsz=224, plots=True)
# Out:
# New https://pypi.org/project/ultralytics/8.0.84 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.83 🚀 Python-3.10.11 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce GTX 1070, 8114MiB)
# ...

# %%
# Evaluate the model's performance on the validation set
results = model.val(plots=True)
# Out:
# Ultralytics YOLOv8.0.83 🚀 Python-3.10.11 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce GTX 1070, 8114MiB)
# Model summary (fused): 168 layers, 11172024 parameters, 0 gradients, 28.7 GFLOPs
# val: Scanning /home/ira-demo/EEfinal_rasp/datasets/dog-breed-yolo_dataset/valid/labels.cache... 3292 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3292/3292 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 206/206 [00:27<00:00,  7.61it/s]
#                    all       3292       3545      0.748       0.72      0.787        0.7
#           Afghan_hound       3292         33       0.84       0.97      0.985      0.919
#    African_hunting_dog       3292         29      0.969      0.828      0.895      0.758
#               Airedale       3292         34      0.893       0.74      0.868      0.814
# American_Staffordshire_terrier       3292         22      0.557      0.455      0.556      0.493
# ...

# %%
# Perform object detection on an image using the model
results = model.predict(source='../Picture/vlc_8TgxGDhtjf.jpg', save=True, save_txt=True)
# Out:
# image 1/1 /home/ira-demo/EEfinal_rasp/Picture/vlc_8TgxGDhtjf.jpg: 128x224 1 Boston_bull, 1 French_bulldog, 84.0ms
# Speed: 0.2ms preprocess, 84.0ms inference, 1.9ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /home/ira-demo/EEfinal_rasp/runs/detect/predict4
# 1 label saved to /home/ira-demo/EEfinal_rasp/runs/detect/predict4/labels
