# %%
from ultralytics import YOLO
import cv2
import json
import math
import numpy as np

# %%
breed_model = YOLO("../runs/detect/train15/weights/best.pt")
pose_model = YOLO("../runs/classify/train15/weights/best.pt")

# %%
with open("../dnn_model/breed/class.json", "r") as f:
    breed_names = json.load(f)
pose_names = {0: 'Lying', 1: 'Sitting', 2: 'Standing'}

# %%
video_path = "../videos/dog_sitting_with_kid.mov"
cap = cv2.VideoCapture(video_path)
WindowName = "Webcam"
color = (255, 0, 0)
font = cv2.FONT_HERSHEY_COMPLEX
FONT_SCALE = 1e-3  # Adjust for larger font size in all images
THICKNESS_SCALE = 1e-3  # Adjust for larger thickness in all images
roi_sapce = 50


cv2.namedWindow(WindowName, cv2.WINDOW_NORMAL)
cv2.resizeWindow(WindowName, 1280, 720)
# These two lines will force your "Main View" window to be on top with focus.
cv2.setWindowProperty(WindowName,cv2.WND_PROP_FULLSCREEN,cv2.WINDOW_FULLSCREEN)
cv2.setWindowProperty(WindowName,cv2.WND_PROP_FULLSCREEN,cv2.WINDOW_NORMAL)

try:
    # Loop through the video frames
    while cap.isOpened():
        # Read a frame from the video
        success, frame = cap.read()

        if success:
            # Run YOLOv8 inference on the frame
            breed_results = breed_model.predict(frame, conf=0.65) #  conf=0.7
            height, width, _ = frame.shape
            font_scale = min(width, height) * FONT_SCALE
            thickness = math.ceil(min(width, height) * THICKNESS_SCALE)
            
            # Object Detection
            breed_boxes = [box.xyxy.to('cpu').tolist() for box in breed_results[0].boxes]
            breed_class_ids = breed_results[0].boxes.cls.to('cpu').tolist()
            breed_scores = breed_results[0].boxes.conf.to('cpu').tolist()
            for breed_classId, breed_score, box in zip(breed_class_ids, breed_scores, breed_boxes):
                box = box[0]
                x, y, w, h = list(map(int, box))
                breed_name = [key for key, value in breed_names.items() if value == breed_classId][0]
                cv2.rectangle(frame, (x, y), (w, h), color, 2)
                cv2.putText(frame, f"Breed: {breed_name} - {breed_score:.3f}", (int(box[0]), int(box[1] - 35)),
                    font, font_scale, color, thickness)
                roi = frame[y - roi_sapce:h + roi_sapce, x - roi_sapce:w + roi_sapce]
                pose_results = pose_model.predict(roi, conf=0.65)
                pose_probs = pose_results[0].probs.cpu()
                pose_score = pose_probs.max().item()
                pose_class_id = np.argmax(pose_probs).item()
                # Object Detection
                pose__name = pose_names[pose_class_id]
                # Add the text to the image
                cv2.putText(frame, f'Pose: {pose__name} - {pose_score:.3f}', (int(box[0]), int(box[1] -5)), font, font_scale, color, thickness)      
                
            cv2.imshow("Webcam", frame)

            # Break the loop if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord("q"):
                break
        else:
            # Break the loop if the end of the video is reached
            break
except Exception as e:
    raise e
finally:
    # Release the video capture object and close the display window
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 0: 128x224 (no detections), 7.2ms
# Speed: 0.3ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.6ms
# Speed: 0.4ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.4ms
# Speed: 0.3ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.2ms
# Speed: 0.3ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.2ms
# Speed: 0.2ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.3ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.1ms
# Speed: 0.2ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.4ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 12.5ms
# Speed: 0.4ms preprocess, 12.5ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 7.1ms
# Speed: 0.2ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.74, Sitting 0.26, Lying 0.00, 7.2ms
# Speed: 0.2ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.1ms
# Speed: 0.3ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.3ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.3ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.5ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.3ms
# Speed: 0.2ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.3ms
# Speed: 0.2ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.72, Standing 0.28, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.3ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.2ms
# Speed: 0.2ms preprocess, 6.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.79, Sitting 0.21, Lying 0.00, 7.4ms
# Speed: 0.2ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.3ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.3ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.4ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.7ms
# Speed: 0.4ms preprocess, 7.7ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.3ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.1ms
# Speed: 0.2ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.3ms
# Speed: 0.2ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 2.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.67, Standing 0.33, Lying 0.01, 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.7ms
# Speed: 0.5ms preprocess, 6.7ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.75, Standing 0.25, Lying 0.01, 7.7ms
# Speed: 0.2ms preprocess, 7.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 8.6ms
# Speed: 0.2ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.5ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.4ms
# Speed: 0.3ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.98, Standing 0.02, Lying 0.00, 7.4ms
# Speed: 0.2ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.96, Standing 0.04, Lying 0.00, 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.59, Sitting 0.41, Lying 0.00, 8.1ms
# Speed: 0.2ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 1.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.55, Sitting 0.45, Lying 0.00, 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 7.2ms
# Speed: 0.3ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.67, Standing 0.33, Lying 0.00, 8.3ms
# Speed: 0.2ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.87, Standing 0.13, Lying 0.00, 7.1ms
# Speed: 0.2ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.80, Standing 0.20, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.84, Standing 0.16, Lying 0.00, 7.5ms
# Speed: 0.2ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.93, Standing 0.07, Lying 0.00, 7.4ms
# Speed: 0.2ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.91, Standing 0.09, Lying 0.00, 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.99, Standing 0.01, Lying 0.00, 7.5ms
# Speed: 0.3ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.3ms
# Speed: 0.2ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.5ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.4ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.3ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.3ms
# Speed: 0.2ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 12.2ms
# Speed: 0.4ms preprocess, 12.2ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.3ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.7ms
# Speed: 0.4ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.7ms
# Speed: 0.6ms preprocess, 6.7ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 1.00, Standing 0.00, Lying 0.00, 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 1.00, Standing 0.00, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.9ms
# Speed: 0.9ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 1.00, Standing 0.00, Lying 0.00, 8.2ms
# Speed: 0.2ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.3ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 18.9ms
# Speed: 0.5ms preprocess, 18.9ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.3ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.6ms
# Speed: 0.2ms preprocess, 7.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.87, Standing 0.13, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.75, Standing 0.25, Lying 0.00, 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.90, Standing 0.10, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 2.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.99, Standing 0.01, Lying 0.00, 7.9ms
# Speed: 0.2ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 1.00, Standing 0.00, Lying 0.00, 7.2ms
# Speed: 0.2ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 1.00, Standing 0.00, Lying 0.00, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 7.0ms
# Speed: 0.3ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.98, Standing 0.02, Lying 0.00, 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.9ms
# Speed: 0.4ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.95, Standing 0.05, Lying 0.00, 7.7ms
# Speed: 0.2ms preprocess, 7.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.91, Standing 0.09, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.97, Standing 0.03, Lying 0.00, 7.2ms
# Speed: 0.2ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 1.00, Standing 0.00, Lying 0.00, 7.2ms
# Speed: 0.2ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.3ms
# Speed: 0.2ms preprocess, 6.3ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.96, Standing 0.04, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.97, Standing 0.03, Lying 0.00, 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 13.5ms
# Speed: 0.3ms preprocess, 13.5ms inference, 2.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.66, Standing 0.34, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.1ms
# Speed: 0.2ms preprocess, 6.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 17.8ms
# Speed: 0.6ms preprocess, 17.8ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.85, Standing 0.13, Lying 0.01, 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.2ms
# Speed: 0.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.4ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.6ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.3ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.1ms
# Speed: 0.3ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.5ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.3ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.3ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.3ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.4ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.8ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.3ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.3ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Chesapeake_Bay_retriever, 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Sitting 0.99, Standing 0.01, Lying 0.00, 7.1ms
# Speed: 0.3ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.3ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.3ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.9ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Brabancon_griffon, 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.84, Sitting 0.16, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.3ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.4ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 11.2ms
# Speed: 0.4ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Brabancon_griffon, 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.98, Sitting 0.02, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Brabancon_griffon, 7.3ms
# Speed: 0.2ms preprocess, 7.3ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.97, Sitting 0.03, Lying 0.00, 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Brabancon_griffon, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.99, Sitting 0.01, Lying 0.00, 7.9ms
# Speed: 0.2ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Brabancon_griffon, 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.93, Sitting 0.07, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Brabancon_griffon, 7.1ms
# Speed: 0.2ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.99, Sitting 0.01, Lying 0.00, 7.2ms
# Speed: 0.2ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Brabancon_griffon, 7.0ms
# Speed: 0.4ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.95, Sitting 0.05, Lying 0.00, 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 1 Brabancon_griffon, 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 Standing 0.82, Sitting 0.18, Lying 0.00, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.3ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.2ms
# Speed: 0.5ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.4ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 11.1ms
# Speed: 0.4ms preprocess, 11.1ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.4ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.3ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# ...
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.3ms
# Speed: 0.2ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.3ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.5ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.2ms
# Speed: 0.3ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.3ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.2ms
# Speed: 0.2ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.3ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 12.4ms
# Speed: 0.5ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.4ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.4ms
# Speed: 0.4ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.3ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.1ms
# Speed: 0.3ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.3ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.3ms
# Speed: 0.2ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.2ms
# Speed: 0.3ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.3ms
# Speed: 0.3ms preprocess, 7.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.3ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.6ms
# Speed: 0.2ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.0ms
# Speed: 0.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.3ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.5ms
# Speed: 0.2ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 22.4ms
# Speed: 0.6ms preprocess, 22.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.8ms
# Speed: 0.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 7.2ms
# Speed: 0.2ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.9ms
# Speed: 0.2ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.7ms
# Speed: 0.3ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 128x224 (no detections), 6.4ms
# Speed: 0.2ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 224)
